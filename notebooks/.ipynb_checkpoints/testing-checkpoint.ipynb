# %%
import requests
import pandas as pd
import os
from PIL import Image
import io
from getpass import getpass
import urllib.request
from io import BytesIO

# %%
MODEL_NAME = "voyage-multimodal-3"

# %%
os.environ["VOYAGEAI_API_KEY"] = (
    os.environ["VOYAGEAI_API_KEY"]
    if "VOYAGEAI_API_KEY" in os.environ
    else getpass("Voyage AI API Key: ")
)

# %%
from voyageai import Client
vo = Client(api_key=os.environ["VOYAGEAI_API_KEY"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from voyageai import Client
#       2 vo = Client(api_key=os.environ["VOYAGEAI_API_KEY"])
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)

# %%
from voyageai import Client

vo = Client(api_key="your_api_key_here")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from voyageai import Client
#       3 vo = Client(api_key="your_api_key_here")
#
# ModuleNotFoundError: No module named 'voyageai'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import voyageai
#       2 print(voyageai.__file__)
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)

# %%
import voyageai
print(voyageai.__file__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import voyageai
#       2 print(voyageai.__file__)
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)

# %%
from voyageai import Client
vo = Client(api_key="your_api_key_here")
print("VoyageAI client ready:", vo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from voyageai import Client
#       2 vo = Client(api_key="your_api_key_here")
#       3 print("VoyageAI client ready:", vo)
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)

# %%
import voyageai
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import voyageai
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)

# %%
import voyageai
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import voyageai
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/__init__.py:29
#      27 from voyageai.client import Client
#      28 from voyageai.client_async import AsyncClient
# ---> 29 from voyageai.embeddings_utils import (
#      30     get_embedding,
#      31     get_embeddings,
#      32     aget_embedding,
#      33     aget_embeddings,
#      34 )
#      36 if TYPE_CHECKING:
#      37     import requests
#
# File ~/PycharmProjects/NASA-WIKI/.venv/lib/python3.12/site-packages/voyageai/embeddings_utils.py:26
#      19 DEFAULT_CONCURRENCE = 1
#      20 DEFAULT_RPM = 300
#      23 @retry(
#      24     wait=wait_random_exponential(min=1, max=20),
#      25     stop=stop_after_attempt(6),
# ---> 26     retry=retry_if_exception_type(voyageai.error.RateLimitError),
#      27 )
#      28 def _get_embeddings(
#      29     list_of_text: List[str],
#      30     model: str = voyageai.VOYAGE_EMBED_DEFAULT_MODEL,
#      31     input_type: Optional[str] = None,
#      32     **kwargs,
#      33 ) -> List[List[float]]:
#      34     """Python wrapper for one Voyage API call."""
#      35     _check_input_type(input_type)
#
# AttributeError: partially initialized module 'voyageai' has no attribute 'error' (most likely due to a circular import)
